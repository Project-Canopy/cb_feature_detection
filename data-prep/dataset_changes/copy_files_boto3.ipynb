# %%
import boto3


s3 = boto3.resource('s3')

bucket_name = 'canopy-production-ml'

pc_bucket = s3.Bucket(bucket_name)

# %%
all_objects = pc_bucket.objects.all()

# %%
yes_chips = []
for obj in all_objects:
    if 'cloudfree-merge-polygons/yes' in obj.key:
        yes_chips.append(obj)
        
len(yes_chips)
# Out:
# 49133

# %%
yes_chips[0].key
# Out:
# 'chips/cloudfree-merge-polygons/yes/Habitation/100/101/101_1000_3000.tif'

# %%
key = yes_chips[0].key

key.split('/')
# Out:
# ['chips',
#  'cloudfree-merge-polygons',
#  'yes',
#  'Habitation',
#  '100',
#  '101',
#  '101_1000_3000.tif']

# %%
split = key.split('/')
split[2] = 'dataset_v2'

'/'.join(split)
# Out:
# 'chips/cloudfree-merge-polygons/dataset_v2/Habitation/100/101/101_1000_3000.tif'

# %%
total = len(yes_chips)

for i, chip in enumerate(yes_chips):
    print(f'Copying chip {i+1} of {total}', end='\r', flush=True)
    
    key = chip.key

    copy_source = {
          'Bucket': bucket_name,
          'Key': key
        }

    key_split = key.split('/')
    key_split[2] = 'dataset_v2'
    new_key = '/'.join(key_split)
    
    pc_bucket.copy(copy_source, new_key)
# Out:
# Copying chip 49133 of 49133

# %%
print(end - start)
# Out:
# 37.38832712173462

# %%
all_chips = []
for obj in all_objects:
    if 'cloudfree-merge-polygons/full' in obj.key:
        all_chips.append(obj)
        
len(all_chips)
# Out:
# 128161

# %%
yes_filenames = [chip.key.split('/')[-1] for chip in yes_chips]

yes_filenames[:10]
# Out:
# ['101_1000_3000.tif',
#  '101_1000_3100.tif',
#  '101_1000_400.tif',
#  '101_1000_500.tif',
#  '101_1100_2600.tif',
#  '101_1100_300.tif',
#  '101_1100_3000.tif',
#  '101_1100_3100.tif',
#  '101_1100_400.tif',
#  '101_1100_500.tif']

# %%
all_chips[0].key
# Out:
# 'chips/cloudfree-merge-polygons/full/1/100/1_0_0.tif'

# %%
all_chips[0].key[-3:]
# Out:
# 'tif'

# %%
no_chips = []

total = len(all_chips)

for i, chip in enumerate(all_chips):
    filename = chip.key.split('/')[-1]
    if filename not in yes_filenames:
        no_chips.append(chip)
        
len(no_chips)
# Out:
# 86390

# %%
import collections


count = collections.Counter(yes_filenames)

duplicates = [i for i in count if count[i] >= 2]

duplicates
# Out:
# ['101_1000_3100.tif',
#  '101_1000_400.tif',
#  '101_1000_500.tif',
#  '101_1100_300.tif',
#  '101_1100_3000.tif',
#  '101_1100_3100.tif',
#  '101_1100_400.tif',
#  '101_1100_500.tif',
#  '101_1200_2600.tif',
#  '101_1200_300.tif',
#  '101_1200_3300.tif',
#  '101_1200_3400.tif',
#  '101_1200_3500.tif',
#  '101_1200_3600.tif',
#  '101_1200_400.tif',
#  '101_1300_1600.tif',
#  '101_1300_1800.tif',
#  '101_1300_3500.tif',
#  '101_1300_3600.tif',
#  '101_1400_1600.tif',
#  '101_1400_1700.tif',
#  '101_1400_2700.tif',
#  '101_1500_2200.tif',
#  '101_1500_2300.tif',
#  '101_1500_2700.tif',
#  '101_1500_2800.tif',
#  '101_1500_3900.tif',
#  '101_1500_4000.tif',
#  '101_1500_4300.tif',
#  '100_700_200.tif',
#  '100_700_400.tif',
#  '100_700_500.tif',
#  '100_700_600.tif',
#  '100_700_700.tif',
#  '100_700_800.tif',
#  '100_700_900.tif',
#  '100_800_100.tif',
#  '100_800_1000.tif',
#  '100_800_1100.tif',
#  '100_800_1400.tif',
#  '100_800_1500.tif',
#  '100_800_1600.tif',
#  '100_800_800.tif',
#  '100_800_900.tif',
#  '100_900_1100.tif',
#  '100_900_1500.tif',
#  '100_900_900.tif',
#  '11_0_300.tif',
#  '11_100_200.tif',
#  '11_100_300.tif',
#  '11_200_200.tif',
#  '11_300_200.tif',
#  '11_400_200.tif',
#  '11_500_200.tif',
#  '11_600_200.tif',
#  '13_1100_700.tif',
#  '13_1100_800.tif',
#  '13_1200_800.tif',
#  '13_1200_900.tif',
#  '13_1300_1000.tif',
#  '13_1300_1100.tif',
#  '13_1300_1200.tif',
#  '13_1300_1300.tif',
#  '13_1300_1400.tif',
#  '13_1300_800.tif',
#  '13_1300_900.tif',
#  '13_1400_1400.tif',
#  '13_1400_1500.tif',
#  '13_1400_1600.tif',
#  '13_1400_1700.tif',
#  '13_1400_1800.tif',
#  '13_1600_1600.tif',
#  '13_1700_1700.tif',
#  '13_1800_1600.tif',
#  '13_1800_1700.tif',
#  '15_1000_700.tif',
#  '15_1000_900.tif',
#  '15_1100_700.tif',
#  '15_1100_900.tif',
#  '15_1200_1000.tif',
#  '15_1200_2300.tif',
#  '15_1200_2400.tif',
#  '15_1200_400.tif',
#  '15_1200_600.tif',
#  '15_1200_700.tif',
#  '15_1200_900.tif',
#  '15_1300_1000.tif',
#  '15_1300_2900.tif',
#  '15_1300_400.tif',
#  '15_1300_500.tif',
#  '15_1300_600.tif',
#  '15_1400_1000.tif',
#  '15_1400_1500.tif',
#  '15_1400_1600.tif',
#  '15_1400_500.tif',
#  '15_1400_600.tif',
#  '15_1400_700.tif',
#  '15_1400_800.tif',
#  '15_1500_1600.tif',
#  '15_1500_1700.tif',
#  '15_1500_500.tif',
#  '15_1500_800.tif',
#  '15_1600_1500.tif',
#  '15_1600_1600.tif',
#  '15_1600_1700.tif',
#  '15_1600_2400.tif',
#  '15_1600_2500.tif',
#  '15_1600_2600.tif',
#  '15_1600_3300.tif',
#  '15_1600_3400.tif',
#  '15_1600_500.tif',
#  '15_1600_600.tif',
#  '15_1600_800.tif',
#  '15_1600_900.tif',
#  '15_1700_1000.tif',
#  '15_1700_1500.tif',
#  '15_1700_1600.tif',
#  '15_1700_2600.tif',
#  '15_1700_3200.tif',
#  '15_1700_3300.tif',
#  '15_1700_500.tif',
#  '15_1700_600.tif',
#  '15_1700_700.tif',
#  '15_1700_800.tif',
#  '15_1700_900.tif',
#  '15_1800_1000.tif',
#  '15_1800_1400.tif',
#  '15_1800_1500.tif',
#  '15_1800_2900.tif',
#  '15_1800_3000.tif',
#  '15_1800_3100.tif',
#  '15_1800_900.tif',
#  '15_1900_1000.tif',
#  '15_1900_1400.tif',
#  '15_1900_2600.tif',
#  '15_1900_2700.tif',
#  '15_1900_2800.tif',
#  '15_1900_3100.tif',
#  '15_2000_1000.tif',
#  '15_2000_1400.tif',
#  '15_2000_1600.tif',
#  '15_2000_1700.tif',
#  '15_2000_1800.tif',
#  '15_2000_1900.tif',
#  '15_2000_2000.tif',
#  '15_2000_2600.tif',
#  '15_2000_3000.tif',
#  '15_2000_3100.tif',
#  '15_2000_900.tif',
#  '15_2100_1400.tif',
#  '15_2100_1500.tif',
#  '15_2100_1700.tif',
#  '15_2100_2000.tif',
#  '15_2100_2600.tif',
#  '15_2100_3000.tif',
#  '15_2100_3100.tif',
#  '15_2100_3200.tif',
#  '15_2200_1600.tif',
#  '15_2200_2300.tif',
#  '15_2200_2400.tif',
#  '15_2200_2500.tif',
#  '15_2200_2900.tif',
#  '15_2200_3000.tif',
#  '15_2200_3200.tif',
#  '15_2200_3300.tif',
#  '15_2300_1600.tif',
#  '15_2300_2900.tif',
#  '15_2400_1600.tif',
#  '15_2400_1700.tif',
#  '15_2400_2800.tif',
#  '15_2400_2900.tif',
#  '15_2500_1700.tif',
#  '15_2600_1700.tif',
#  '15_700_1000.tif',
#  '15_700_600.tif',
#  '15_800_1000.tif',
#  '15_800_600.tif',
#  '15_800_900.tif',
#  '15_900_900.tif',
#  '16_1000_1100.tif',
#  '16_1000_1700.tif',
#  '16_100_400.tif',
#  '16_100_500.tif',
#  '16_1100_1200.tif',
#  '16_1100_1700.tif',
#  '16_1100_1800.tif',
#  '16_1200_1200.tif',
#  '16_1200_1300.tif',
#  '16_1200_1400.tif',
#  '16_1200_1500.tif',
#  '16_1200_1700.tif',
#  '16_1300_1200.tif',
#  '16_1300_1500.tif',
#  '16_1300_1600.tif',
#  '16_1300_1700.tif',
#  '16_1400_1200.tif',
#  '16_1400_1300.tif',
#  '16_1400_1400.tif',
#  '16_1400_1500.tif',
#  '16_1400_1600.tif',
#  '16_1400_1700.tif',
#  '16_1500_1400.tif',
#  '16_1500_1500.tif',
#  '16_1500_1600.tif',
#  '16_1500_1700.tif',
#  '16_1500_1800.tif',
#  '16_1600_1700.tif',
#  '16_200_400.tif',
#  '16_200_500.tif',
#  '16_200_600.tif',
#  '16_200_700.tif',
#  '16_300_700.tif',
#  '16_300_800.tif',
#  '16_300_900.tif',
#  '16_400_1000.tif',
#  '16_400_1100.tif',
#  '16_400_700.tif',
#  '16_400_900.tif',
#  '16_500_1000.tif',
#  '16_500_1100.tif',
#  '16_500_1200.tif',
#  '16_500_500.tif',
#  '16_500_600.tif',
#  '16_500_700.tif',
#  '16_500_900.tif',
#  '16_600_1200.tif',
#  '16_600_1700.tif',
#  '16_600_400.tif',
#  '16_600_500.tif',
#  '16_600_600.tif',
#  '16_600_700.tif',
#  '16_600_800.tif',
#  '16_600_900.tif',
#  '16_700_1000.tif',
#  '16_700_1100.tif',
#  '16_700_1200.tif',
#  '16_700_1700.tif',
#  '16_700_400.tif',
#  '16_700_600.tif',
#  '16_700_800.tif',
#  '16_700_900.tif',
#  '16_800_1100.tif',
#  '16_800_1500.tif',
#  ...]

# %%
odd_keys
# Out:
# []

# %%
assert len(yes_chips) + len(no_chips) == len(all_chips)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-20-cdb3e2452eba> in <module>
# ----> 1 assert len(yes_chips) + len(no_chips) == len(all_chips)
#
# AssertionError:

# %%
len(yes_chips) + len(no_chips)
# Out:
# 135523

# %%
len(all_chips)
# Out:
# 128161

# %%
chip_filenames = [chip.key.split('/')[-1] for chip in all_chips]

missing = []

total = len(yes_chips)

for i, chip in enumerate(yes_chips):
    print(f'Chip {i+1} of {total}', end='\r', flush=True)
    
    if chip.key.split('/')[-1] not in chip_filenames:
        missing.append(chip.key)
        
len(missing)
# Out:
# Chip 12345 of 49133
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Chip 49133 of 49133
# 5

# %%
missing
# Out:
# ['chips/cloudfree-merge-polygons/yes/ISL/100/1/1_300_1000.tif.aux.xml',
#  'chips/cloudfree-merge-polygons/yes/ISL/100/1/1_300_1100.tif.aux.xml',
#  'chips/cloudfree-merge-polygons/yes/ISL/100/1/1_400_700.tif.aux.xml',
#  'chips/cloudfree-merge-polygons/yes/ISL/100/1/1_400_800.tif.aux.xml',
#  'chips/cloudfree-merge-polygons/yes/ISL/100/1/1_400_900.tif.aux.xml']

# %%
len(no_chips)
# Out:
# 86390

# %%
def boto3_copy_objs(keys, old_bucket_name, new_bucket,
                    folder_change_dict=None, folder_add_dict=None, folder_swap_dict=None):
    total = len(keys)
    
    for i, key in enumerate(keys):
        print(f'Copying object {i+1} of {total}', end='\r', flush=True)
        
        copy_source = {
            'Bucket': old_bucket_name,
            'Key': key
        }
        
        key_split = key.split('/')
        
        if folder_change_dict:
            for k in folder_change_dict:
                try:
                    key_split[k] = folder_change_dict[k]
                except:
                    raise ValueError('Error when applying the folder_change_dict')
                
        if folder_add_dict:
            for k in folder_add_dict:
                try:
                    key_split.insert(k, folder_add_dict[k])
                except:
                    raise ValueError('Error when applying the folder_add_dict')
                    
        if folder_swap_dict:
            for k in folder_swap_dict:
                i = folder_swap_dict[k]
                try:
                    key_split[k], key_split[i] = key_split[i], key_split[k]
                except:
                    raise ValueError('Error when applying the folder_swap_dict')
                
        new_key = '/'.join(key_split)
        
        #print(new_key)
        
        new_bucket.copy(copy_source, new_key)

# %%
no_chips[0].key
# Out:
# 'chips/cloudfree-merge-polygons/full/1/100/1_0_0.tif'

# %%
boto3_copy_objs(no_chips, bucket_name, pc_bucket, {2: 'dataset_v2'}, {3: 'misc'}, {4: 5})
# Out:
# Copying object 86390 of 86390

# %%
keep_cats = ['ISL', 'Roads', 'Industrial_agriculture', 'Shifting_cultivation', 'Mining']

keep_filenames = []

for obj in all_objects:
    for category in keep_cats:
        if f'cloudfree-merge-polygons/dataset_v2/{category}' in obj.key:
            filename = obj.key.split('/')[-1]
            keep_filenames.append(filename)

# %%
len(keep_filenames)
# Out:
# 14025

# %%
keep_filenames[0]
# Out:
# '1_1000_1000.tif'

# %%
remove_cats = ['River', 'Rainforest', 'Water', 'Savanna', 'Habitation']

move_chips = []

delete_chips = []

for obj in all_objects:
    for category in remove_cats:
        if f'cloudfree-merge-polygons/dataset_v2/{category}' in obj.key:
            filename = obj.key.split('/')[-1]
            if filename not in keep_filenames:
                move_chips.append(obj)
            else:
                delete_chips.append(obj)

# %%
len(move_chips) + len(delete_chips)
# Out:
# 35108

# %%
import pandas as pd


data = {'Keys': [chip.key for chip in move_chips]}

df = pd.DataFrame(data=data)

df.head()
# Out:
#                                                 Keys
# 0  chips/cloudfree-merge-polygons/dataset_v2/Habi...
# 1  chips/cloudfree-merge-polygons/dataset_v2/Habi...
# 2  chips/cloudfree-merge-polygons/dataset_v2/Habi...
# 3  chips/cloudfree-merge-polygons/dataset_v2/Habi...
# 4  chips/cloudfree-merge-polygons/dataset_v2/Habi...

# %%
df['Filenames'] = df['Keys'].apply(lambda x:x.split('/')[-1])

df.head()
# Out:
#                                                 Keys          Filenames
# 0  chips/cloudfree-merge-polygons/dataset_v2/Habi...  101_1000_3000.tif
# 1  chips/cloudfree-merge-polygons/dataset_v2/Habi...  101_1000_3100.tif
# 2  chips/cloudfree-merge-polygons/dataset_v2/Habi...  101_1100_2600.tif
# 3  chips/cloudfree-merge-polygons/dataset_v2/Habi...  101_1100_3000.tif
# 4  chips/cloudfree-merge-polygons/dataset_v2/Habi...  101_1100_3100.tif

# %%
print(df.shape)

df2 = df.drop_duplicates(subset=['Filenames'])

print(df2.shape)
# Out:
# (30226, 2)
# (28577, 2)

# %%
move_chips_no_dupes = df2['Keys'].tolist()

len(move_chips_no_dupes)
# Out:
# 28577

# %%
move_chips_no_dupes[0]
# Out:
# 'chips/cloudfree-merge-polygons/dataset_v2/Habitation/100/101/101_1000_3000.tif'

# %%
boto3_copy_objs(move_chips_no_dupes, bucket_name, pc_bucket, {3: 'misc'})
# Out:
# Copying object 28577 of 28577

# %%
delete_chips_full = move_chips + delete_chips

len(delete_chips_full)
# Out:
# 35108

# %%
# delete_objs_list = [{'Key': chip.key for chip in delete_chips_full}]

# %%
#client = boto3.client('s3')

#response = client.delete_objects(
#    Bucket=bucket_name,
#    Delete=delete_objs_list
#)

# %% [markdown]
# ### train/test split based off polygons

# %%
all_objects = pc_bucket.objects.all()

all_chips = []

for obj in all_objects:
    if 'cloudfree-merge-polygons/dataset_v2/' in obj.key:
        all_chips.append(obj)
        
print(len(all_chips))

print(all_chips[0].key)
# Out:
# 128994
# chips/cloudfree-merge-polygons/dataset_v2/

# %%
all_chips[1].key
# Out:
# 'chips/cloudfree-merge-polygons/dataset_v2/ISL/100/1/1_1000_1000.tif'

# %%
assert 'chips/cloudfree-merge-polygons/dataset_v2/ISL/' in all_chips
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-48-68bf2170f949> in <module>
# ----> 1 assert 'chips/cloudfree-merge-polygons/dataset_v2/ISL/' in all_chips
#
# AssertionError:

# %%
chip_count = {}

for chip in all_chips:
    key = chip.key
    
    try:
        poly_id = key.split('/')[5]

        if poly_id in chip_count.keys():
            chip_count[poly_id] += 1
        else:
            chip_count[poly_id] = 1
            
    except:
        print(key)
# Out:
# chips/cloudfree-merge-polygons/dataset_v2/
# chips/cloudfree-merge-polygons/dataset_v2/misc/

# %%
sum(chip_count.values())
# Out:
# 128992

# %%
chip_count
# Out:
# {'1': 559,
#  '100': 336,
#  '11': 56,
#  '13': 550,
#  '15': 1400,
#  '16': 418,
#  '17': 799,
#  '2': 262,
#  '20': 1025,
#  '21': 1152,
#  '22': 1710,
#  '24': 210,
#  '25': 1240,
#  '26': 256,
#  '29': 1548,
#  '3': 110,
#  '30': 509,
#  '32': 1591,
#  '33': 845,
#  '34': 100,
#  '35': 304,
#  '36': 792,
#  '37': 899,
#  '38': 500,
#  '39': 1620,
#  '40': 306,
#  '41': 272,
#  '42': 456,
#  '43': 110,
#  '44': 1824,
#  '46': 210,
#  '47': 182,
#  '48': 1833,
#  '5': 399,
#  '53': 1185,
#  '54': 90,
#  '55': 3036,
#  '59': 1189,
#  '62': 195,
#  '64': 994,
#  '65': 294,
#  '68': 961,
#  '70': 420,
#  '72': 1292,
#  '73': 36,
#  '74': 3658,
#  '75': 4680,
#  '76': 440,
#  '77': 780,
#  '79': 528,
#  '82': 899,
#  '83': 456,
#  '84': 611,
#  '85': 3424,
#  '88': 858,
#  '89': 2977,
#  '90': 88,
#  '91': 1184,
#  '93': 211,
#  '94': 48,
#  '99': 456,
#  '10': 2843,
#  '27': 708,
#  '31': 1440,
#  '49': 1545,
#  '52': 1411,
#  '58': 832,
#  '6': 450,
#  '87': 48,
#  '9': 1292,
#  '4': 34,
#  '61': 20,
#  '63': 72,
#  '69': 460,
#  '8': 121,
#  '86': 832,
#  '101': 1980,
#  '14': 812,
#  '19': 1955,
#  '45': 256,
#  '56': 1233,
#  '66': 1822,
#  '92': 4994,
#  '51': 154,
#  '81': 16577,
#  '12': 2538,
#  '18': 2091,
#  '23': 960,
#  '28': 1702,
#  '50': 2450,
#  '57': 2544,
#  '60': 7839,
#  '67': 3657,
#  '7': 2322,
#  '71': 81,
#  '78': 3888,
#  '80': 1656}

# %%
import json


json_object = json.dumps(chip_count)

with open('chip_count.json', 'w') as fp:
    json.dump(chip_count, fp)

# %%
bucket_name = 'canopy-production-ml-output'
my_bucket = s3.Bucket(bucket_name)
path = 'ckpt/pc-tf-custom-container-2021-04-14-15-15-52-166/'

h5_files = [obj.key for obj in my_bucket.objects.filter(Prefix=path) if obj.key[-2:] == 'h5']

h5_files
# Out:
# ['ckpt/pc-tf-custom-container-2021-04-14-15-15-52-166/last_chkpt.h5',
#  'ckpt/pc-tf-custom-container-2021-04-14-15-15-52-166/model_resnet_epoch_1.h5',
#  'ckpt/pc-tf-custom-container-2021-04-14-15-15-52-166/model_resnet_epoch_10.h5',
#  'ckpt/pc-tf-custom-container-2021-04-14-15-15-52-166/model_resnet_epoch_11.h5',
#  'ckpt/pc-tf-custom-container-2021-04-14-15-15-52-166/model_resnet_epoch_12.h5',
#  'ckpt/pc-tf-custom-container-2021-04-14-15-15-52-166/model_resnet_epoch_13.h5',
#  'ckpt/pc-tf-custom-container-2021-04-14-15-15-52-166/model_resnet_epoch_14.h5',
#  'ckpt/pc-tf-custom-container-2021-04-14-15-15-52-166/model_resnet_epoch_15.h5',
#  'ckpt/pc-tf-custom-container-2021-04-14-15-15-52-166/model_resnet_epoch_16.h5',
#  'ckpt/pc-tf-custom-container-2021-04-14-15-15-52-166/model_resnet_epoch_17.h5',
#  'ckpt/pc-tf-custom-container-2021-04-14-15-15-52-166/model_resnet_epoch_18.h5',
#  'ckpt/pc-tf-custom-container-2021-04-14-15-15-52-166/model_resnet_epoch_19.h5',
#  'ckpt/pc-tf-custom-container-2021-04-14-15-15-52-166/model_resnet_epoch_2.h5',
#  'ckpt/pc-tf-custom-container-2021-04-14-15-15-52-166/model_resnet_epoch_20.h5',
#  'ckpt/pc-tf-custom-container-2021-04-14-15-15-52-166/model_resnet_epoch_21.h5',
#  'ckpt/pc-tf-custom-container-2021-04-14-15-15-52-166/model_resnet_epoch_22.h5',
#  'ckpt/pc-tf-custom-container-2021-04-14-15-15-52-166/model_resnet_epoch_23.h5',
#  'ckpt/pc-tf-custom-container-2021-04-14-15-15-52-166/model_resnet_epoch_24.h5',
#  'ckpt/pc-tf-custom-container-2021-04-14-15-15-52-166/model_resnet_epoch_25.h5',
#  'ckpt/pc-tf-custom-container-2021-04-14-15-15-52-166/model_resnet_epoch_26.h5',
#  'ckpt/pc-tf-custom-container-2021-04-14-15-15-52-166/model_resnet_epoch_3.h5',
#  'ckpt/pc-tf-custom-container-2021-04-14-15-15-52-166/model_resnet_epoch_4.h5',
#  'ckpt/pc-tf-custom-container-2021-04-14-15-15-52-166/model_resnet_epoch_5.h5',
#  'ckpt/pc-tf-custom-container-2021-04-14-15-15-52-166/model_resnet_epoch_6.h5',
#  'ckpt/pc-tf-custom-container-2021-04-14-15-15-52-166/model_resnet_epoch_7.h5',
#  'ckpt/pc-tf-custom-container-2021-04-14-15-15-52-166/model_resnet_epoch_8.h5',
#  'ckpt/pc-tf-custom-container-2021-04-14-15-15-52-166/model_resnet_epoch_9.h5']

# %%
h5_files = h5_files[1:]

# %%
h5_files_dict = {}

for file in h5_files:
    key = int(file.split('_')[-1].split('.')[0])
    h5_files_dict[key] = file
    
h5_files_dict
# Out:
# {1: 'ckpt/pc-tf-custom-container-2021-04-14-15-15-52-166/model_resnet_epoch_1.h5',
#  10: 'ckpt/pc-tf-custom-container-2021-04-14-15-15-52-166/model_resnet_epoch_10.h5',
#  11: 'ckpt/pc-tf-custom-container-2021-04-14-15-15-52-166/model_resnet_epoch_11.h5',
#  12: 'ckpt/pc-tf-custom-container-2021-04-14-15-15-52-166/model_resnet_epoch_12.h5',
#  13: 'ckpt/pc-tf-custom-container-2021-04-14-15-15-52-166/model_resnet_epoch_13.h5',
#  14: 'ckpt/pc-tf-custom-container-2021-04-14-15-15-52-166/model_resnet_epoch_14.h5',
#  15: 'ckpt/pc-tf-custom-container-2021-04-14-15-15-52-166/model_resnet_epoch_15.h5',
#  16: 'ckpt/pc-tf-custom-container-2021-04-14-15-15-52-166/model_resnet_epoch_16.h5',
#  17: 'ckpt/pc-tf-custom-container-2021-04-14-15-15-52-166/model_resnet_epoch_17.h5',
#  18: 'ckpt/pc-tf-custom-container-2021-04-14-15-15-52-166/model_resnet_epoch_18.h5',
#  19: 'ckpt/pc-tf-custom-container-2021-04-14-15-15-52-166/model_resnet_epoch_19.h5',
#  2: 'ckpt/pc-tf-custom-container-2021-04-14-15-15-52-166/model_resnet_epoch_2.h5',
#  20: 'ckpt/pc-tf-custom-container-2021-04-14-15-15-52-166/model_resnet_epoch_20.h5',
#  21: 'ckpt/pc-tf-custom-container-2021-04-14-15-15-52-166/model_resnet_epoch_21.h5',
#  22: 'ckpt/pc-tf-custom-container-2021-04-14-15-15-52-166/model_resnet_epoch_22.h5',
#  23: 'ckpt/pc-tf-custom-container-2021-04-14-15-15-52-166/model_resnet_epoch_23.h5',
#  24: 'ckpt/pc-tf-custom-container-2021-04-14-15-15-52-166/model_resnet_epoch_24.h5',
#  25: 'ckpt/pc-tf-custom-container-2021-04-14-15-15-52-166/model_resnet_epoch_25.h5',
#  26: 'ckpt/pc-tf-custom-container-2021-04-14-15-15-52-166/model_resnet_epoch_26.h5',
#  3: 'ckpt/pc-tf-custom-container-2021-04-14-15-15-52-166/model_resnet_epoch_3.h5',
#  4: 'ckpt/pc-tf-custom-container-2021-04-14-15-15-52-166/model_resnet_epoch_4.h5',
#  5: 'ckpt/pc-tf-custom-container-2021-04-14-15-15-52-166/model_resnet_epoch_5.h5',
#  6: 'ckpt/pc-tf-custom-container-2021-04-14-15-15-52-166/model_resnet_epoch_6.h5',
#  7: 'ckpt/pc-tf-custom-container-2021-04-14-15-15-52-166/model_resnet_epoch_7.h5',
#  8: 'ckpt/pc-tf-custom-container-2021-04-14-15-15-52-166/model_resnet_epoch_8.h5',
#  9: 'ckpt/pc-tf-custom-container-2021-04-14-15-15-52-166/model_resnet_epoch_9.h5'}

# %%
max_epoch = max(h5_files_dict)

h5_files_dict[max_epoch]
# Out:
# 'ckpt/pc-tf-custom-container-2021-04-14-15-15-52-166/model_resnet_epoch_26.h5'

# %%
max(h5_files_dict.keys())
# Out:
# 26

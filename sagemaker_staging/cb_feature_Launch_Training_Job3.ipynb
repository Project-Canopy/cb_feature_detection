# %%
# Notebook Instance Imports
import os
import sagemaker
from sagemaker.tensorflow import TensorFlow
from sagemaker import get_execution_role
from sagemaker.estimator import Estimator

# %% [markdown]
# # Identify Data Location

# %%
# S3 directories

training_files = "s3://canopy-production-ml/training_inputs/"
# val_file = "s3://canopy-production-ml/training_inputs/val_labels.csv"
# labels_file = "s3://canopy-production-ml/training_inputs/labels.json"

inputs = {"data":training_files}

print(inputs)
# Out:
# {'data': 's3://canopy-production-ml/training_inputs/'}

# %% [markdown]
# # Custom Docker for Training

# %%
# %cd docker_test_folder
# Out:
# /home/ec2-user/SageMaker/cb_feature_detection/sagemaker_staging/docker_test_folder

# %%
# !pwd
# Out:
# /home/ec2-user/SageMaker/cb_feature_detection/sagemaker_staging/docker_test_folder

# %%
! aws ecr get-login-password --region us-east-1 | docker login --username AWS --password-stdin 763104351884.dkr.ecr.us-east-1.amazonaws.com
# Out:
# WARNING! Your password will be stored unencrypted in /home/ec2-user/.docker/config.json.
# Configure a credential helper to remove this warning. See
# https://docs.docker.com/engine/reference/commandline/login/#credentials-store
#
# Login Succeeded

# %%
! docker build -t tf-custom-container-test .
# Out:
# Sending build context to Docker daemon  35.33kB
# Step 1/5 : FROM 763104351884.dkr.ecr.us-east-1.amazonaws.com/tensorflow-training:2.4.1-cpu-py37-ubuntu18.04
#  ---> a6b6eae32037
# Step 2/5 : ENV PATH="/opt/ml/code:${PATH}"
#  ---> Using cache
#  ---> 8294093ffa21
# Step 3/5 : RUN pip3 install rasterio keras
#  ---> Using cache
#  ---> db9d1558d609
# Step 4/5 : COPY cb_feature_train1_aws.py /opt/ml/code/train.py
#  ---> 4f8682a4daf2
# Step 5/5 : ENV SAGEMAKER_PROGRAM train.py
#  ---> Running in 0f7eb0b242f9
# Removing intermediate container 0f7eb0b242f9
#  ---> beb1b3a5cfec
# Successfully built beb1b3a5cfec
# Successfully tagged tf-custom-container-test:latest

# %% [markdown]
# # For Local Container test - Success

# %%
from sagemaker.estimator import Estimator

estimator = Estimator(image_uri='tf-custom-container-test',
                      role='arn:aws:iam::963659202518:role/service-role/AmazonSageMaker-ExecutionRole-20210306T191865',
                      instance_count=1,
                      instance_type='local')

estimator.fit(inputs)
# Out:
# Creating qb0fdmh9hb-algo-1-hleiy ...
# Creating qb0fdmh9hb-algo-1-hleiy ... done
# Attaching to qb0fdmh9hb-algo-1-hleiy
# qb0fdmh9hb-algo-1-hleiy | 2021-03-07 16:53:43.886754: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# qb0fdmh9hb-algo-1-hleiy | 2021-03-07 16:53:43.886942: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:105] SageMaker Profiler is not enabled. The timeline writer thread will not be started, future recorded events will be dropped.
# qb0fdmh9hb-algo-1-hleiy | 2021-03-07 16:53:43.918195: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# qb0fdmh9hb-algo-1-hleiy | 2021-03-07 16:53:45,598 sagemaker-training-toolkit INFO     Imported framework sagemaker_tensorflow_container.training
# qb0fdmh9hb-algo-1-hleiy | 2021-03-07 16:53:45,605 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# qb0fdmh9hb-algo-1-hleiy | 2021-03-07 16:53:45,627 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# qb0fdmh9hb-algo-1-hleiy | 2021-03-07 16:53:45,648 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# qb0fdmh9hb-algo-1-hleiy | 2021-03-07 16:53:45,668 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# qb0fdmh9hb-algo-1-hleiy | 2021-03-07 16:53:45,681 sagemaker-training-toolkit INFO     Invoking user script
# qb0fdmh9hb-algo-1-hleiy |
# qb0fdmh9hb-algo-1-hleiy | Training Env:
# qb0fdmh9hb-algo-1-hleiy |
# qb0fdmh9hb-algo-1-hleiy | {
# qb0fdmh9hb-algo-1-hleiy |     "additional_framework_parameters": {},
# qb0fdmh9hb-algo-1-hleiy |     "channel_input_dirs": {
# qb0fdmh9hb-algo-1-hleiy |         "data": "/opt/ml/input/data/data"
# qb0fdmh9hb-algo-1-hleiy |     },
# qb0fdmh9hb-algo-1-hleiy |     "current_host": "algo-1-hleiy",
# qb0fdmh9hb-algo-1-hleiy |     "framework_module": "sagemaker_tensorflow_container.training:main",
# qb0fdmh9hb-algo-1-hleiy |     "hosts": [
# qb0fdmh9hb-algo-1-hleiy |         "algo-1-hleiy"
# qb0fdmh9hb-algo-1-hleiy |     ],
# qb0fdmh9hb-algo-1-hleiy |     "hyperparameters": {},
# qb0fdmh9hb-algo-1-hleiy |     "input_config_dir": "/opt/ml/input/config",
# qb0fdmh9hb-algo-1-hleiy |     "input_data_config": {
# qb0fdmh9hb-algo-1-hleiy |         "data": {
# qb0fdmh9hb-algo-1-hleiy |             "TrainingInputMode": "File"
# qb0fdmh9hb-algo-1-hleiy |         }
# qb0fdmh9hb-algo-1-hleiy |     },
# qb0fdmh9hb-algo-1-hleiy |     "input_dir": "/opt/ml/input",
# qb0fdmh9hb-algo-1-hleiy |     "is_master": true,
# qb0fdmh9hb-algo-1-hleiy |     "job_name": "tf-custom-container-test-2021-03-07-16-53-41-446",
# qb0fdmh9hb-algo-1-hleiy |     "log_level": 20,
# qb0fdmh9hb-algo-1-hleiy |     "master_hostname": "algo-1-hleiy",
# qb0fdmh9hb-algo-1-hleiy |     "model_dir": "/opt/ml/model",
# qb0fdmh9hb-algo-1-hleiy |     "module_dir": "/opt/ml/code",
# qb0fdmh9hb-algo-1-hleiy |     "module_name": "train",
# qb0fdmh9hb-algo-1-hleiy |     "network_interface_name": "eth0",
# qb0fdmh9hb-algo-1-hleiy |     "num_cpus": 2,
# qb0fdmh9hb-algo-1-hleiy |     "num_gpus": 0,
# qb0fdmh9hb-algo-1-hleiy |     "output_data_dir": "/opt/ml/output/data",
# qb0fdmh9hb-algo-1-hleiy |     "output_dir": "/opt/ml/output",
# qb0fdmh9hb-algo-1-hleiy |     "output_intermediate_dir": "/opt/ml/output/intermediate",
# qb0fdmh9hb-algo-1-hleiy |     "resource_config": {
# qb0fdmh9hb-algo-1-hleiy |         "current_host": "algo-1-hleiy",
# qb0fdmh9hb-algo-1-hleiy |         "hosts": [
# qb0fdmh9hb-algo-1-hleiy |             "algo-1-hleiy"
# qb0fdmh9hb-algo-1-hleiy |         ]
# qb0fdmh9hb-algo-1-hleiy |     },
# qb0fdmh9hb-algo-1-hleiy |     "user_entry_point": "train.py"
# qb0fdmh9hb-algo-1-hleiy | }
# qb0fdmh9hb-algo-1-hleiy |
# qb0fdmh9hb-algo-1-hleiy | Environment variables:
# qb0fdmh9hb-algo-1-hleiy |
# qb0fdmh9hb-algo-1-hleiy | SM_HOSTS=["algo-1-hleiy"]
# qb0fdmh9hb-algo-1-hleiy | SM_NETWORK_INTERFACE_NAME=eth0
# qb0fdmh9hb-algo-1-hleiy | SM_HPS={}
# qb0fdmh9hb-algo-1-hleiy | SM_USER_ENTRY_POINT=train.py
# qb0fdmh9hb-algo-1-hleiy | SM_FRAMEWORK_PARAMS={}
# qb0fdmh9hb-algo-1-hleiy | SM_RESOURCE_CONFIG={"current_host":"algo-1-hleiy","hosts":["algo-1-hleiy"]}
# qb0fdmh9hb-algo-1-hleiy | SM_INPUT_DATA_CONFIG={"data":{"TrainingInputMode":"File"}}
# qb0fdmh9hb-algo-1-hleiy | SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# qb0fdmh9hb-algo-1-hleiy | SM_CHANNELS=["data"]
# qb0fdmh9hb-algo-1-hleiy | SM_CURRENT_HOST=algo-1-hleiy
# qb0fdmh9hb-algo-1-hleiy | SM_MODULE_NAME=train
# qb0fdmh9hb-algo-1-hleiy | SM_LOG_LEVEL=20
# qb0fdmh9hb-algo-1-hleiy | SM_FRAMEWORK_MODULE=sagemaker_tensorflow_container.training:main
# qb0fdmh9hb-algo-1-hleiy | SM_INPUT_DIR=/opt/ml/input
# qb0fdmh9hb-algo-1-hleiy | SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# qb0fdmh9hb-algo-1-hleiy | SM_OUTPUT_DIR=/opt/ml/output
# qb0fdmh9hb-algo-1-hleiy | SM_NUM_CPUS=2
# qb0fdmh9hb-algo-1-hleiy | SM_NUM_GPUS=0
# qb0fdmh9hb-algo-1-hleiy | SM_MODEL_DIR=/opt/ml/model
# qb0fdmh9hb-algo-1-hleiy | SM_MODULE_DIR=/opt/ml/code
# qb0fdmh9hb-algo-1-hleiy | SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"data":"/opt/ml/input/data/data"},"current_host":"algo-1-hleiy","framework_module":"sagemaker_tensorflow_container.training:main","hosts":["algo-1-hleiy"],"hyperparameters":{},"input_config_dir":"/opt/ml/input/config","input_data_config":{"data":{"TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"tf-custom-container-test-2021-03-07-16-53-41-446","log_level":20,"master_hostname":"algo-1-hleiy","model_dir":"/opt/ml/model","module_dir":"/opt/ml/code","module_name":"train","network_interface_name":"eth0","num_cpus":2,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1-hleiy","hosts":["algo-1-hleiy"]},"user_entry_point":"train.py"}
# qb0fdmh9hb-algo-1-hleiy | SM_USER_ARGS=[]
# qb0fdmh9hb-algo-1-hleiy | SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# qb0fdmh9hb-algo-1-hleiy | SM_CHANNEL_DATA=/opt/ml/input/data/data
# qb0fdmh9hb-algo-1-hleiy | PYTHONPATH=/opt/ml/code:/usr/local/bin:/usr/local/lib/python37.zip:/usr/local/lib/python3.7:/usr/local/lib/python3.7/lib-dynload:/usr/local/lib/python3.7/site-packages
# qb0fdmh9hb-algo-1-hleiy |
# qb0fdmh9hb-algo-1-hleiy | Invoking script with the following command:
# qb0fdmh9hb-algo-1-hleiy |
# qb0fdmh9hb-algo-1-hleiy | /usr/local/bin/python3.7 train.py
# qb0fdmh9hb-algo-1-hleiy |
# qb0fdmh9hb-algo-1-hleiy |
# qb0fdmh9hb-algo-1-hleiy | Data augmentation enabled
# qb0fdmh9hb-algo-1-hleiy | Training on 200 images
# qb0fdmh9hb-algo-1-hleiy | Validation on 366 images
# qb0fdmh9hb-algo-1-hleiy | Your training file is missing positive labels for classes ['0', '2', '3', '7', '8', '9']
# qb0fdmh9hb-algo-1-hleiy | [2021-03-07 16:53:48.424 b733e36c29e4:18 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# qb0fdmh9hb-algo-1-hleiy | [2021-03-07 16:53:48.667 b733e36c29e4:18 INFO profiler_config_parser.py:102] Unable to find config at /opt/ml/input/config/profilerconfig.json. Profiler is disabled.
# qb0fdmh9hb-algo-1-hleiy | Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94773248/94765736 [==============================] - 1s 0us/step
# qb0fdmh9hb-algo-1-hleiy | Model: "model"
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | Layer (type)                    Output Shape         Param #     Connected to
# qb0fdmh9hb-algo-1-hleiy | ==================================================================================================
# qb0fdmh9hb-algo-1-hleiy | input_1 (InputLayer)            [(None, 100, 100, 18 0
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv2d (Conv2D)                 (None, 100, 100, 3)  57          input_1[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv1_pad (ZeroPadding2D)       (None, 106, 106, 3)  0           conv2d[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv1_conv (Conv2D)             (None, 50, 50, 64)   9472        conv1_pad[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv1_bn (BatchNormalization)   (None, 50, 50, 64)   256         conv1_conv[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv1_relu (Activation)         (None, 50, 50, 64)   0           conv1_bn[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | pool1_pad (ZeroPadding2D)       (None, 52, 52, 64)   0           conv1_relu[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | pool1_pool (MaxPooling2D)       (None, 25, 25, 64)   0           pool1_pad[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv2_block1_1_conv (Conv2D)    (None, 25, 25, 64)   4160        pool1_pool[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv2_block1_1_bn (BatchNormali (None, 25, 25, 64)   256         conv2_block1_1_conv[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv2_block1_1_relu (Activation (None, 25, 25, 64)   0           conv2_block1_1_bn[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv2_block1_2_conv (Conv2D)    (None, 25, 25, 64)   36928       conv2_block1_1_relu[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv2_block1_2_bn (BatchNormali (None, 25, 25, 64)   256         conv2_block1_2_conv[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv2_block1_2_relu (Activation (None, 25, 25, 64)   0           conv2_block1_2_bn[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv2_block1_0_conv (Conv2D)    (None, 25, 25, 256)  16640       pool1_pool[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv2_block1_3_conv (Conv2D)    (None, 25, 25, 256)  16640       conv2_block1_2_relu[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv2_block1_0_bn (BatchNormali (None, 25, 25, 256)  1024        conv2_block1_0_conv[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv2_block1_3_bn (BatchNormali (None, 25, 25, 256)  1024        conv2_block1_3_conv[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv2_block1_add (Add)          (None, 25, 25, 256)  0           conv2_block1_0_bn[0][0]
# qb0fdmh9hb-algo-1-hleiy |                                                                  conv2_block1_3_bn[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv2_block1_out (Activation)   (None, 25, 25, 256)  0           conv2_block1_add[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv2_block2_1_conv (Conv2D)    (None, 25, 25, 64)   16448       conv2_block1_out[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv2_block2_1_bn (BatchNormali (None, 25, 25, 64)   256         conv2_block2_1_conv[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv2_block2_1_relu (Activation (None, 25, 25, 64)   0           conv2_block2_1_bn[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv2_block2_2_conv (Conv2D)    (None, 25, 25, 64)   36928       conv2_block2_1_relu[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv2_block2_2_bn (BatchNormali (None, 25, 25, 64)   256         conv2_block2_2_conv[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv2_block2_2_relu (Activation (None, 25, 25, 64)   0           conv2_block2_2_bn[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv2_block2_3_conv (Conv2D)    (None, 25, 25, 256)  16640       conv2_block2_2_relu[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv2_block2_3_bn (BatchNormali (None, 25, 25, 256)  1024        conv2_block2_3_conv[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv2_block2_add (Add)          (None, 25, 25, 256)  0           conv2_block1_out[0][0]
# qb0fdmh9hb-algo-1-hleiy |                                                                  conv2_block2_3_bn[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv2_block2_out (Activation)   (None, 25, 25, 256)  0           conv2_block2_add[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv2_block3_1_conv (Conv2D)    (None, 25, 25, 64)   16448       conv2_block2_out[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv2_block3_1_bn (BatchNormali (None, 25, 25, 64)   256         conv2_block3_1_conv[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv2_block3_1_relu (Activation (None, 25, 25, 64)   0           conv2_block3_1_bn[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv2_block3_2_conv (Conv2D)    (None, 25, 25, 64)   36928       conv2_block3_1_relu[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv2_block3_2_bn (BatchNormali (None, 25, 25, 64)   256         conv2_block3_2_conv[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv2_block3_2_relu (Activation (None, 25, 25, 64)   0           conv2_block3_2_bn[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv2_block3_3_conv (Conv2D)    (None, 25, 25, 256)  16640       conv2_block3_2_relu[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv2_block3_3_bn (BatchNormali (None, 25, 25, 256)  1024        conv2_block3_3_conv[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv2_block3_add (Add)          (None, 25, 25, 256)  0           conv2_block2_out[0][0]
# qb0fdmh9hb-algo-1-hleiy |                                                                  conv2_block3_3_bn[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv2_block3_out (Activation)   (None, 25, 25, 256)  0           conv2_block3_add[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv3_block1_1_conv (Conv2D)    (None, 13, 13, 128)  32896       conv2_block3_out[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv3_block1_1_bn (BatchNormali (None, 13, 13, 128)  512         conv3_block1_1_conv[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv3_block1_1_relu (Activation (None, 13, 13, 128)  0           conv3_block1_1_bn[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv3_block1_2_conv (Conv2D)    (None, 13, 13, 128)  147584      conv3_block1_1_relu[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv3_block1_2_bn (BatchNormali (None, 13, 13, 128)  512         conv3_block1_2_conv[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv3_block1_2_relu (Activation (None, 13, 13, 128)  0           conv3_block1_2_bn[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv3_block1_0_conv (Conv2D)    (None, 13, 13, 512)  131584      conv2_block3_out[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv3_block1_3_conv (Conv2D)    (None, 13, 13, 512)  66048       conv3_block1_2_relu[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv3_block1_0_bn (BatchNormali (None, 13, 13, 512)  2048        conv3_block1_0_conv[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv3_block1_3_bn (BatchNormali (None, 13, 13, 512)  2048        conv3_block1_3_conv[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv3_block1_add (Add)          (None, 13, 13, 512)  0           conv3_block1_0_bn[0][0]
# qb0fdmh9hb-algo-1-hleiy |                                                                  conv3_block1_3_bn[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv3_block1_out (Activation)   (None, 13, 13, 512)  0           conv3_block1_add[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv3_block2_1_conv (Conv2D)    (None, 13, 13, 128)  65664       conv3_block1_out[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv3_block2_1_bn (BatchNormali (None, 13, 13, 128)  512         conv3_block2_1_conv[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv3_block2_1_relu (Activation (None, 13, 13, 128)  0           conv3_block2_1_bn[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv3_block2_2_conv (Conv2D)    (None, 13, 13, 128)  147584      conv3_block2_1_relu[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv3_block2_2_bn (BatchNormali (None, 13, 13, 128)  512         conv3_block2_2_conv[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv3_block2_2_relu (Activation (None, 13, 13, 128)  0           conv3_block2_2_bn[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv3_block2_3_conv (Conv2D)    (None, 13, 13, 512)  66048       conv3_block2_2_relu[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv3_block2_3_bn (BatchNormali (None, 13, 13, 512)  2048        conv3_block2_3_conv[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv3_block2_add (Add)          (None, 13, 13, 512)  0           conv3_block1_out[0][0]
# qb0fdmh9hb-algo-1-hleiy |                                                                  conv3_block2_3_bn[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv3_block2_out (Activation)   (None, 13, 13, 512)  0           conv3_block2_add[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv3_block3_1_conv (Conv2D)    (None, 13, 13, 128)  65664       conv3_block2_out[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv3_block3_1_bn (BatchNormali (None, 13, 13, 128)  512         conv3_block3_1_conv[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv3_block3_1_relu (Activation (None, 13, 13, 128)  0           conv3_block3_1_bn[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv3_block3_2_conv (Conv2D)    (None, 13, 13, 128)  147584      conv3_block3_1_relu[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv3_block3_2_bn (BatchNormali (None, 13, 13, 128)  512         conv3_block3_2_conv[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv3_block3_2_relu (Activation (None, 13, 13, 128)  0           conv3_block3_2_bn[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv3_block3_3_conv (Conv2D)    (None, 13, 13, 512)  66048       conv3_block3_2_relu[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv3_block3_3_bn (BatchNormali (None, 13, 13, 512)  2048        conv3_block3_3_conv[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv3_block3_add (Add)          (None, 13, 13, 512)  0           conv3_block2_out[0][0]
# qb0fdmh9hb-algo-1-hleiy |                                                                  conv3_block3_3_bn[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv3_block3_out (Activation)   (None, 13, 13, 512)  0           conv3_block3_add[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv3_block4_1_conv (Conv2D)    (None, 13, 13, 128)  65664       conv3_block3_out[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv3_block4_1_bn (BatchNormali (None, 13, 13, 128)  512         conv3_block4_1_conv[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv3_block4_1_relu (Activation (None, 13, 13, 128)  0           conv3_block4_1_bn[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv3_block4_2_conv (Conv2D)    (None, 13, 13, 128)  147584      conv3_block4_1_relu[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv3_block4_2_bn (BatchNormali (None, 13, 13, 128)  512         conv3_block4_2_conv[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv3_block4_2_relu (Activation (None, 13, 13, 128)  0           conv3_block4_2_bn[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv3_block4_3_conv (Conv2D)    (None, 13, 13, 512)  66048       conv3_block4_2_relu[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv3_block4_3_bn (BatchNormali (None, 13, 13, 512)  2048        conv3_block4_3_conv[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv3_block4_add (Add)          (None, 13, 13, 512)  0           conv3_block3_out[0][0]
# qb0fdmh9hb-algo-1-hleiy |                                                                  conv3_block4_3_bn[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv3_block4_out (Activation)   (None, 13, 13, 512)  0           conv3_block4_add[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv4_block1_1_conv (Conv2D)    (None, 7, 7, 256)    131328      conv3_block4_out[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv4_block1_1_bn (BatchNormali (None, 7, 7, 256)    1024        conv4_block1_1_conv[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv4_block1_1_relu (Activation (None, 7, 7, 256)    0           conv4_block1_1_bn[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv4_block1_2_conv (Conv2D)    (None, 7, 7, 256)    590080      conv4_block1_1_relu[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv4_block1_2_bn (BatchNormali (None, 7, 7, 256)    1024        conv4_block1_2_conv[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv4_block1_2_relu (Activation (None, 7, 7, 256)    0           conv4_block1_2_bn[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv4_block1_0_conv (Conv2D)    (None, 7, 7, 1024)   525312      conv3_block4_out[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv4_block1_3_conv (Conv2D)    (None, 7, 7, 1024)   263168      conv4_block1_2_relu[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv4_block1_0_bn (BatchNormali (None, 7, 7, 1024)   4096        conv4_block1_0_conv[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv4_block1_3_bn (BatchNormali (None, 7, 7, 1024)   4096        conv4_block1_3_conv[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv4_block1_add (Add)          (None, 7, 7, 1024)   0           conv4_block1_0_bn[0][0]
# qb0fdmh9hb-algo-1-hleiy |                                                                  conv4_block1_3_bn[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv4_block1_out (Activation)   (None, 7, 7, 1024)   0           conv4_block1_add[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv4_block2_1_conv (Conv2D)    (None, 7, 7, 256)    262400      conv4_block1_out[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv4_block2_1_bn (BatchNormali (None, 7, 7, 256)    1024        conv4_block2_1_conv[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv4_block2_1_relu (Activation (None, 7, 7, 256)    0           conv4_block2_1_bn[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv4_block2_2_conv (Conv2D)    (None, 7, 7, 256)    590080      conv4_block2_1_relu[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv4_block2_2_bn (BatchNormali (None, 7, 7, 256)    1024        conv4_block2_2_conv[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv4_block2_2_relu (Activation (None, 7, 7, 256)    0           conv4_block2_2_bn[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv4_block2_3_conv (Conv2D)    (None, 7, 7, 1024)   263168      conv4_block2_2_relu[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv4_block2_3_bn (BatchNormali (None, 7, 7, 1024)   4096        conv4_block2_3_conv[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv4_block2_add (Add)          (None, 7, 7, 1024)   0           conv4_block1_out[0][0]
# qb0fdmh9hb-algo-1-hleiy |                                                                  conv4_block2_3_bn[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv4_block2_out (Activation)   (None, 7, 7, 1024)   0           conv4_block2_add[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv4_block3_1_conv (Conv2D)    (None, 7, 7, 256)    262400      conv4_block2_out[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv4_block3_1_bn (BatchNormali (None, 7, 7, 256)    1024        conv4_block3_1_conv[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv4_block3_1_relu (Activation (None, 7, 7, 256)    0           conv4_block3_1_bn[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv4_block3_2_conv (Conv2D)    (None, 7, 7, 256)    590080      conv4_block3_1_relu[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv4_block3_2_bn (BatchNormali (None, 7, 7, 256)    1024        conv4_block3_2_conv[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv4_block3_2_relu (Activation (None, 7, 7, 256)    0           conv4_block3_2_bn[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv4_block3_3_conv (Conv2D)    (None, 7, 7, 1024)   263168      conv4_block3_2_relu[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv4_block3_3_bn (BatchNormali (None, 7, 7, 1024)   4096        conv4_block3_3_conv[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv4_block3_add (Add)          (None, 7, 7, 1024)   0           conv4_block2_out[0][0]
# qb0fdmh9hb-algo-1-hleiy |                                                                  conv4_block3_3_bn[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv4_block3_out (Activation)   (None, 7, 7, 1024)   0           conv4_block3_add[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv4_block4_1_conv (Conv2D)    (None, 7, 7, 256)    262400      conv4_block3_out[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv4_block4_1_bn (BatchNormali (None, 7, 7, 256)    1024        conv4_block4_1_conv[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv4_block4_1_relu (Activation (None, 7, 7, 256)    0           conv4_block4_1_bn[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv4_block4_2_conv (Conv2D)    (None, 7, 7, 256)    590080      conv4_block4_1_relu[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv4_block4_2_bn (BatchNormali (None, 7, 7, 256)    1024        conv4_block4_2_conv[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv4_block4_2_relu (Activation (None, 7, 7, 256)    0           conv4_block4_2_bn[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv4_block4_3_conv (Conv2D)    (None, 7, 7, 1024)   263168      conv4_block4_2_relu[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv4_block4_3_bn (BatchNormali (None, 7, 7, 1024)   4096        conv4_block4_3_conv[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv4_block4_add (Add)          (None, 7, 7, 1024)   0           conv4_block3_out[0][0]
# qb0fdmh9hb-algo-1-hleiy |                                                                  conv4_block4_3_bn[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv4_block4_out (Activation)   (None, 7, 7, 1024)   0           conv4_block4_add[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv4_block5_1_conv (Conv2D)    (None, 7, 7, 256)    262400      conv4_block4_out[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv4_block5_1_bn (BatchNormali (None, 7, 7, 256)    1024        conv4_block5_1_conv[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv4_block5_1_relu (Activation (None, 7, 7, 256)    0           conv4_block5_1_bn[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv4_block5_2_conv (Conv2D)    (None, 7, 7, 256)    590080      conv4_block5_1_relu[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv4_block5_2_bn (BatchNormali (None, 7, 7, 256)    1024        conv4_block5_2_conv[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv4_block5_2_relu (Activation (None, 7, 7, 256)    0           conv4_block5_2_bn[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv4_block5_3_conv (Conv2D)    (None, 7, 7, 1024)   263168      conv4_block5_2_relu[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv4_block5_3_bn (BatchNormali (None, 7, 7, 1024)   4096        conv4_block5_3_conv[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv4_block5_add (Add)          (None, 7, 7, 1024)   0           conv4_block4_out[0][0]
# qb0fdmh9hb-algo-1-hleiy |                                                                  conv4_block5_3_bn[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv4_block5_out (Activation)   (None, 7, 7, 1024)   0           conv4_block5_add[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv4_block6_1_conv (Conv2D)    (None, 7, 7, 256)    262400      conv4_block5_out[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv4_block6_1_bn (BatchNormali (None, 7, 7, 256)    1024        conv4_block6_1_conv[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv4_block6_1_relu (Activation (None, 7, 7, 256)    0           conv4_block6_1_bn[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv4_block6_2_conv (Conv2D)    (None, 7, 7, 256)    590080      conv4_block6_1_relu[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv4_block6_2_bn (BatchNormali (None, 7, 7, 256)    1024        conv4_block6_2_conv[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv4_block6_2_relu (Activation (None, 7, 7, 256)    0           conv4_block6_2_bn[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv4_block6_3_conv (Conv2D)    (None, 7, 7, 1024)   263168      conv4_block6_2_relu[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv4_block6_3_bn (BatchNormali (None, 7, 7, 1024)   4096        conv4_block6_3_conv[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv4_block6_add (Add)          (None, 7, 7, 1024)   0           conv4_block5_out[0][0]
# qb0fdmh9hb-algo-1-hleiy |                                                                  conv4_block6_3_bn[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv4_block6_out (Activation)   (None, 7, 7, 1024)   0           conv4_block6_add[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv5_block1_1_conv (Conv2D)    (None, 4, 4, 512)    524800      conv4_block6_out[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv5_block1_1_bn (BatchNormali (None, 4, 4, 512)    2048        conv5_block1_1_conv[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv5_block1_1_relu (Activation (None, 4, 4, 512)    0           conv5_block1_1_bn[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv5_block1_2_conv (Conv2D)    (None, 4, 4, 512)    2359808     conv5_block1_1_relu[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv5_block1_2_bn (BatchNormali (None, 4, 4, 512)    2048        conv5_block1_2_conv[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv5_block1_2_relu (Activation (None, 4, 4, 512)    0           conv5_block1_2_bn[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv5_block1_0_conv (Conv2D)    (None, 4, 4, 2048)   2099200     conv4_block6_out[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv5_block1_3_conv (Conv2D)    (None, 4, 4, 2048)   1050624     conv5_block1_2_relu[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv5_block1_0_bn (BatchNormali (None, 4, 4, 2048)   8192        conv5_block1_0_conv[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv5_block1_3_bn (BatchNormali (None, 4, 4, 2048)   8192        conv5_block1_3_conv[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv5_block1_add (Add)          (None, 4, 4, 2048)   0           conv5_block1_0_bn[0][0]
# qb0fdmh9hb-algo-1-hleiy |                                                                  conv5_block1_3_bn[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv5_block1_out (Activation)   (None, 4, 4, 2048)   0           conv5_block1_add[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv5_block2_1_conv (Conv2D)    (None, 4, 4, 512)    1049088     conv5_block1_out[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv5_block2_1_bn (BatchNormali (None, 4, 4, 512)    2048        conv5_block2_1_conv[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv5_block2_1_relu (Activation (None, 4, 4, 512)    0           conv5_block2_1_bn[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv5_block2_2_conv (Conv2D)    (None, 4, 4, 512)    2359808     conv5_block2_1_relu[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv5_block2_2_bn (BatchNormali (None, 4, 4, 512)    2048        conv5_block2_2_conv[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv5_block2_2_relu (Activation (None, 4, 4, 512)    0           conv5_block2_2_bn[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv5_block2_3_conv (Conv2D)    (None, 4, 4, 2048)   1050624     conv5_block2_2_relu[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv5_block2_3_bn (BatchNormali (None, 4, 4, 2048)   8192        conv5_block2_3_conv[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv5_block2_add (Add)          (None, 4, 4, 2048)   0           conv5_block1_out[0][0]
# qb0fdmh9hb-algo-1-hleiy |                                                                  conv5_block2_3_bn[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv5_block2_out (Activation)   (None, 4, 4, 2048)   0           conv5_block2_add[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv5_block3_1_conv (Conv2D)    (None, 4, 4, 512)    1049088     conv5_block2_out[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv5_block3_1_bn (BatchNormali (None, 4, 4, 512)    2048        conv5_block3_1_conv[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv5_block3_1_relu (Activation (None, 4, 4, 512)    0           conv5_block3_1_bn[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv5_block3_2_conv (Conv2D)    (None, 4, 4, 512)    2359808     conv5_block3_1_relu[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv5_block3_2_bn (BatchNormali (None, 4, 4, 512)    2048        conv5_block3_2_conv[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv5_block3_2_relu (Activation (None, 4, 4, 512)    0           conv5_block3_2_bn[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv5_block3_3_conv (Conv2D)    (None, 4, 4, 2048)   1050624     conv5_block3_2_relu[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv5_block3_3_bn (BatchNormali (None, 4, 4, 2048)   8192        conv5_block3_3_conv[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv5_block3_add (Add)          (None, 4, 4, 2048)   0           conv5_block2_out[0][0]
# qb0fdmh9hb-algo-1-hleiy |                                                                  conv5_block3_3_bn[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | conv5_block3_out (Activation)   (None, 4, 4, 2048)   0           conv5_block3_add[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | global_average_pooling2d (Globa (None, 2048)         0           conv5_block3_out[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | dense (Dense)                   (None, 2048)         4196352     global_average_pooling2d[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | dense_1 (Dense)                 (None, 2048)         4196352     dense[0][0]
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | dense_2 (Dense)                 (None, 10)           20490       dense_1[0][0]
# qb0fdmh9hb-algo-1-hleiy | ==================================================================================================
# qb0fdmh9hb-algo-1-hleiy | Total params: 32,000,963
# qb0fdmh9hb-algo-1-hleiy | Trainable params: 31,947,843
# qb0fdmh9hb-algo-1-hleiy | Non-trainable params: 53,120
# qb0fdmh9hb-algo-1-hleiy | __________________________________________________________________________________________________
# qb0fdmh9hb-algo-1-hleiy | Epoch 1/20
# 10/10 [==============================] - 57s 5s/step - loss: 0.6955 - accuracy: 0.9136 - val_loss: 0.7297 - val_accuracy: 0.8331
# qb0fdmh9hb-algo-1-hleiy |
# qb0fdmh9hb-algo-1-hleiy | Epoch 00001: val_loss improved from inf to 0.72975, saving model to checkpoint_1234.h5
# qb0fdmh9hb-algo-1-hleiy | Epoch 2/20
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/anaconda3/envs/amazonei_tensorflow2_p36/lib/python3.6/site-packages/sagemaker/local/image.py in train(self, input_data_config, output_data_config, hyperparameters, job_name)
#     236         try:
# --> 237             _stream_output(process)
#     238         except RuntimeError as e:
#
# ~/anaconda3/envs/amazonei_tensorflow2_p36/lib/python3.6/site-packages/sagemaker/local/image.py in _stream_output(process)
#     881     while exit_code is None:
# --> 882         stdout = process.stdout.readline().decode("utf-8")
#     883         sys.stdout.write(stdout)
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-6b0caeb3c017> in <module>
#       6                       instance_type='local')
#       7
# ----> 8 estimator.fit(inputs)
#
# ~/anaconda3/envs/amazonei_tensorflow2_p36/lib/python3.6/site-packages/sagemaker/estimator.py in fit(self, inputs, wait, logs, job_name, experiment_config)
#     656         self._prepare_for_training(job_name=job_name)
#     657
# --> 658         self.latest_training_job = _TrainingJob.start_new(self, inputs, experiment_config)
#     659         self.jobs.append(self.latest_training_job)
#     660         if wait:
#
# ~/anaconda3/envs/amazonei_tensorflow2_p36/lib/python3.6/site-packages/sagemaker/estimator.py in start_new(cls, estimator, inputs, experiment_config)
#    1419         """
#    1420         train_args = cls._get_train_args(estimator, inputs, experiment_config)
# -> 1421         estimator.sagemaker_session.train(**train_args)
#    1422
#    1423         return cls(estimator.sagemaker_session, estimator._current_job_name)
#
# ~/anaconda3/envs/amazonei_tensorflow2_p36/lib/python3.6/site-packages/sagemaker/session.py in train(self, input_mode, input_config, role, job_name, output_config, resource_config, vpc_config, hyperparameters, stop_condition, tags, metric_definitions, enable_network_isolation, image_uri, algorithm_arn, encrypt_inter_container_traffic, use_spot_instances, checkpoint_s3_uri, checkpoint_local_path, experiment_config, debugger_rule_configs, debugger_hook_config, tensorboard_output_config, enable_sagemaker_metrics, profiler_rule_configs, profiler_config)
#     560         LOGGER.info("Creating training-job with name: %s", job_name)
#     561         LOGGER.debug("train request: %s", json.dumps(train_request, indent=4))
# --> 562         self.sagemaker_client.create_training_job(**train_request)
#     563
#     564     def _get_train_request(  # noqa: C901
#
# ~/anaconda3/envs/amazonei_tensorflow2_p36/lib/python3.6/site-packages/sagemaker/local/local_session.py in create_training_job(self, TrainingJobName, AlgorithmSpecification, OutputDataConfig, ResourceConfig, InputDataConfig, **kwargs)
#     184         hyperparameters = kwargs["HyperParameters"] if "HyperParameters" in kwargs else {}
#     185         logger.info("Starting training job")
# --> 186         training_job.start(InputDataConfig, OutputDataConfig, hyperparameters, TrainingJobName)
#     187
#     188         LocalSagemakerClient._training_jobs[TrainingJobName] = training_job
#
# ~/anaconda3/envs/amazonei_tensorflow2_p36/lib/python3.6/site-packages/sagemaker/local/entities.py in start(self, input_data_config, output_data_config, hyperparameters, job_name)
#     219
#     220         self.model_artifacts = self.container.train(
# --> 221             input_data_config, output_data_config, hyperparameters, job_name
#     222         )
#     223         self.end_time = datetime.datetime.now()
#
# ~/anaconda3/envs/amazonei_tensorflow2_p36/lib/python3.6/site-packages/sagemaker/local/image.py in train(self, input_data_config, output_data_config, hyperparameters, job_name)
#     242             raise RuntimeError(msg)
#     243         finally:
# --> 244             artifacts = self.retrieve_artifacts(compose_data, output_data_config, job_name)
#     245
#     246             # free up the training data directory as it may contain
#
# ~/anaconda3/envs/amazonei_tensorflow2_p36/lib/python3.6/site-packages/sagemaker/local/image.py in retrieve_artifacts(self, compose_data, output_data_config, job_name)
#     369                 output_data_config["S3OutputPath"],
#     370                 job_name,
# --> 371                 self.sagemaker_session,
#     372             )
#     373
#
# ~/anaconda3/envs/amazonei_tensorflow2_p36/lib/python3.6/site-packages/sagemaker/local/utils.py in move_to_destination(source, destination, job_name, sagemaker_session)
#      70         path = s3.s3_path_join(parsed_uri.path, job_name)
#      71         final_uri = s3.s3_path_join("s3://", bucket, path)
# ---> 72         sagemaker_session.upload_data(source, bucket, path)
#      73     else:
#      74         raise ValueError("Invalid destination URI, must be s3:// or file://, got: %s" % destination)
#
# ~/anaconda3/envs/amazonei_tensorflow2_p36/lib/python3.6/site-packages/sagemaker/session.py in upload_data(self, path, bucket, key_prefix, extra_args)
#     225
#     226         for local_path, s3_key in files:
# --> 227             s3.Object(bucket, s3_key).upload_file(local_path, ExtraArgs=extra_args)
#     228
#     229         s3_uri = "s3://{}/{}".format(bucket, key_prefix)
#
# ~/anaconda3/envs/amazonei_tensorflow2_p36/lib/python3.6/site-packages/boto3/s3/inject.py in object_upload_file(self, Filename, ExtraArgs, Callback, Config)
#     278     return self.meta.client.upload_file(
#     279         Filename=Filename, Bucket=self.bucket_name, Key=self.key,
# --> 280         ExtraArgs=ExtraArgs, Callback=Callback, Config=Config)
#     281
#     282
#
# ~/anaconda3/envs/amazonei_tensorflow2_p36/lib/python3.6/site-packages/boto3/s3/inject.py in upload_file(self, Filename, Bucket, Key, ExtraArgs, Callback, Config)
#     129         return transfer.upload_file(
#     130             filename=Filename, bucket=Bucket, key=Key,
# --> 131             extra_args=ExtraArgs, callback=Callback)
#     132
#     133
#
# ~/anaconda3/envs/amazonei_tensorflow2_p36/lib/python3.6/site-packages/boto3/s3/transfer.py in upload_file(self, filename, bucket, key, callback, extra_args)
#     277             filename, bucket, key, extra_args, subscribers)
#     278         try:
# --> 279             future.result()
#     280         # If a client error was raised, add the backwards compatibility layer
#     281         # that raises a S3UploadFailedError. These specific errors were only
#
# ~/anaconda3/envs/amazonei_tensorflow2_p36/lib/python3.6/site-packages/s3transfer/futures.py in result(self)
#     107         except KeyboardInterrupt as e:
#     108             self.cancel()
# --> 109             raise e
#     110
#     111     def cancel(self):
#
# ~/anaconda3/envs/amazonei_tensorflow2_p36/lib/python3.6/site-packages/s3transfer/futures.py in result(self)
#     104             # however if a KeyboardInterrupt is raised we want want to exit
#     105             # out of this and propogate the exception.
# --> 106             return self._coordinator.result()
#     107         except KeyboardInterrupt as e:
#     108             self.cancel()
#
# ~/anaconda3/envs/amazonei_tensorflow2_p36/lib/python3.6/site-packages/s3transfer/futures.py in result(self)
#     258         # possible value integer value, which is on the scale of billions of
#     259         # years...
# --> 260         self._done_event.wait(MAXINT)
#     261
#     262         # Once done waiting, raise an exception if present or return the
#
# ~/anaconda3/envs/amazonei_tensorflow2_p36/lib/python3.6/threading.py in wait(self, timeout)
#     549             signaled = self._flag
#     550             if not signaled:
# --> 551                 signaled = self._cond.wait(timeout)
#     552             return signaled
#     553
#
# ~/anaconda3/envs/amazonei_tensorflow2_p36/lib/python3.6/threading.py in wait(self, timeout)
#     293         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     294             if timeout is None:
# --> 295                 waiter.acquire()
#     296                 gotit = True
#     297             else:
#
# KeyboardInterrupt:

# %% [markdown]
# # Publish Container to ECR

# %%
# %%sh
#
# # Specify an algorithm name
# algorithm_name=pc-tf-custom-container-test
#
# account=$(aws sts get-caller-identity --query Account --output text)
#
# # Get the region defined in the current configuration (default to us-west-2 if none defined)
# region=$(aws configure get region)
# region=${region:-us-west-2}
#
# fullname="${account}.dkr.ecr.${region}.amazonaws.com/${algorithm_name}:latest"
#
# # If the repository doesn't exist in ECR, create it.
#
# aws ecr describe-repositories --repository-names "${algorithm_name}" > /dev/null 2>&1
# if [ $? -ne 0 ]
# then
# aws ecr create-repository --repository-name "${algorithm_name}" > /dev/null
# fi
#
# # Get the login command from ECR and execute it directly
#
# $(aws ecr get-login --region ${region} --no-include-email)
#
# # Build the docker image locally with the image name and then push it to ECR
# # with the full name.
#
# docker build -t ${algorithm_name} .
# docker tag ${algorithm_name} ${fullname}
#
# docker push ${fullname}
# Out:
# Login Succeeded
# Sending build context to Docker daemon  35.33kB
# Step 1/5 : FROM 763104351884.dkr.ecr.us-east-1.amazonaws.com/tensorflow-training:2.4.1-cpu-py37-ubuntu18.04
#  ---> a6b6eae32037
# Step 2/5 : ENV PATH="/opt/ml/code:${PATH}"
#  ---> Using cache
#  ---> 8294093ffa21
# Step 3/5 : RUN pip3 install rasterio keras
#  ---> Using cache
#  ---> db9d1558d609
# Step 4/5 : COPY cb_feature_train1_aws.py /opt/ml/code/train.py
#  ---> Using cache
#  ---> 4f8682a4daf2
# Step 5/5 : ENV SAGEMAKER_PROGRAM train.py
#  ---> Using cache
#  ---> beb1b3a5cfec
# Successfully built beb1b3a5cfec
# Successfully tagged pc-tf-custom-container-test:latest
# The push refers to repository [963659202518.dkr.ecr.us-east-1.amazonaws.com/pc-tf-custom-container-test]
# a224793cc443: Preparing
# ad96c940e8e7: Preparing
# 0859a4046b5c: Preparing
# 13a6259d0a5f: Preparing
# 7c9b17058a17: Preparing
# e64228f78c01: Preparing
# a4b459577f83: Preparing
# 2c6530437d13: Preparing
# 24a74e1f08ab: Preparing
# 1dc8a537c9f8: Preparing
# 805fb593f0a3: Preparing
# aa1d9c35ff1e: Preparing
# 753f9be13b18: Preparing
# e7c48ae4f19f: Preparing
# fcb9704bd126: Preparing
# 3299a84d1836: Preparing
# d563b978c640: Preparing
# 9f10818f1f96: Preparing
# 27502392e386: Preparing
# c95d2191d777: Preparing
# aa1d9c35ff1e: Waiting
# 753f9be13b18: Waiting
# e7c48ae4f19f: Waiting
# e64228f78c01: Waiting
# a4b459577f83: Waiting
# 2c6530437d13: Waiting
# 24a74e1f08ab: Waiting
# 1dc8a537c9f8: Waiting
# 805fb593f0a3: Waiting
# fcb9704bd126: Waiting
# 3299a84d1836: Waiting
# d563b978c640: Waiting
# 9f10818f1f96: Waiting
# 27502392e386: Waiting
# c95d2191d777: Waiting
# a224793cc443: Layer already exists
# ad96c940e8e7: Layer already exists
# 13a6259d0a5f: Layer already exists
# 7c9b17058a17: Layer already exists
# 0859a4046b5c: Layer already exists
# a4b459577f83: Layer already exists
# 24a74e1f08ab: Layer already exists
# 2c6530437d13: Layer already exists
# 1dc8a537c9f8: Layer already exists
# 805fb593f0a3: Layer already exists
# aa1d9c35ff1e: Layer already exists
# e7c48ae4f19f: Layer already exists
# 753f9be13b18: Layer already exists
# fcb9704bd126: Layer already exists
# 3299a84d1836: Layer already exists
# 9f10818f1f96: Layer already exists
# 27502392e386: Layer already exists
# c95d2191d777: Layer already exists
# d563b978c640: Pushed
# e64228f78c01: Pushed
# latest: digest: sha256:8b179e2e0162936b9b7429b1ba6237d04177baa02ab8d4bc64f57ff05d8cb59d size: 4510
# WARNING! Using --password via the CLI is insecure. Use --password-stdin.
# WARNING! Your password will be stored unencrypted in /home/ec2-user/.docker/config.json.
# Configure a credential helper to remove this warning. See
# https://docs.docker.com/engine/reference/commandline/login/#credentials-store

# %%
import boto3

account_id = boto3.client('sts').get_caller_identity().get('Account')
ecr_repository = 'sagemaker-byoc-test'
tag = ':latest'

region = boto3.session.Session().region_name

uri_suffix = 'amazonaws.com'
if region in ['cn-north-1', 'cn-northwest-1']:
    uri_suffix = 'amazonaws.com.cn'

byoc_image_uri = '{}.dkr.ecr.{}.{}/{}'.format(account_id, region, uri_suffix, ecr_repository + tag)

byoc_image_uri
# This should return something like
# 111122223333.dkr.ecr.us-east-2.amazonaws.com/sagemaker-byoc-test:latest
# Out:
# '963659202518.dkr.ecr.us-east-1.amazonaws.com/sagemaker-byoc-test:latest'

# %% [markdown]
# # For ECR Run

# %% [markdown]
# ## Identify Data Location

# %%
# S3 directories

training_files = "s3://canopy-production-ml/training_inputs/"
# val_file = "s3://canopy-production-ml/training_inputs/val_labels.csv"
# labels_file = "s3://canopy-production-ml/training_inputs/labels.json"

inputs = {"data":training_files}

print(inputs)
# Out:
# {'data': 's3://canopy-production-ml/training_inputs/'}

# %%
image_uri = '963659202518.dkr.ecr.us-east-1.amazonaws.com/sagemaker-byoc-test:latest'

# create estimator
estimator = Estimator(image_uri=image_uri,
                       instance_type='ml.p2.xlarge',
                       output_path='s3://canopy-production-ml-output',
                       base_job_name='pc-tf-custom-container-test-job',
                       instance_count=1,
                       role=get_execution_role(), # Passes to the container the AWS role that you are using on this notebook
                       py_version='py37')

# %%
estimator.fit(inputs)
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# <ipython-input-16-0731e612c7b1> in <module>
# ----> 1 estimator.fit(inputs)
#
# ~/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/sagemaker/estimator.py in fit(self, inputs, wait, logs, job_name, experiment_config)
#     656         self._prepare_for_training(job_name=job_name)
#     657
# --> 658         self.latest_training_job = _TrainingJob.start_new(self, inputs, experiment_config)
#     659         self.jobs.append(self.latest_training_job)
#     660         if wait:
#
# ~/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/sagemaker/estimator.py in start_new(cls, estimator, inputs, experiment_config)
#    1419         """
#    1420         train_args = cls._get_train_args(estimator, inputs, experiment_config)
# -> 1421         estimator.sagemaker_session.train(**train_args)
#    1422
#    1423         return cls(estimator.sagemaker_session, estimator._current_job_name)
#
# ~/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/sagemaker/session.py in train(self, input_mode, input_config, role, job_name, output_config, resource_config, vpc_config, hyperparameters, stop_condition, tags, metric_definitions, enable_network_isolation, image_uri, algorithm_arn, encrypt_inter_container_traffic, use_spot_instances, checkpoint_s3_uri, checkpoint_local_path, experiment_config, debugger_rule_configs, debugger_hook_config, tensorboard_output_config, enable_sagemaker_metrics, profiler_rule_configs, profiler_config)
#     560         LOGGER.info("Creating training-job with name: %s", job_name)
#     561         LOGGER.debug("train request: %s", json.dumps(train_request, indent=4))
# --> 562         self.sagemaker_client.create_training_job(**train_request)
#     563
#     564     def _get_train_request(  # noqa: C901
#
# ~/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/botocore/client.py in _api_call(self, *args, **kwargs)
#     355                     "%s() only accepts keyword arguments." % py_operation_name)
#     356             # The "self" in this scope is referring to the BaseClient.
# --> 357             return self._make_api_call(operation_name, kwargs)
#     358
#     359         _api_call.__name__ = str(py_operation_name)
#
# ~/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/botocore/client.py in _make_api_call(self, operation_name, api_params)
#     674             error_code = parsed_response.get("Error", {}).get("Code")
#     675             error_class = self.exceptions.from_code(error_code)
# --> 676             raise error_class(parsed_response, operation_name)
#     677         else:
#     678             return parsed_response
#
# ClientError: An error occurred (ValidationException) when calling the CreateTrainingJob operation: Cannot find repository: sagemaker-byoc-test in registry ID: 963659202518 Please check if your ECR repository exists and role arn:aws:iam::963659202518:role/service-role/AmazonSageMaker-ExecutionRole-20210306T191865 has proper pull permissions for SageMaker: ecr:BatchCheckLayerAvailability, ecr:BatchGetImage, ecr:GetDownloadUrlForLayer
